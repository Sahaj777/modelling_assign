# %% [markdown]
# # eda

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering as AC
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_excel('c:/users/gaurav yadav/downloads/EastWestAirlines (1).xlsx',sheet_name='data')

df.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
def range_x(x):
    return (np.min(x),np.max(x))
for i in range(1,12):
    print(df.columns[i],range_x(df.iloc[:,i]),end=' ')
    print()
# from range of values it is evident that cc1_miles,cc2_miles,cc3_miles,award column doesn't provide much info(less variance)
# so dropping those columns
# Out:
# Balance (0, 1704838)
# Qual_miles (0, 11148)
# cc1_miles (1, 5)
# cc2_miles (1, 3)
# cc3_miles (1, 5)
# Bonus_miles (0, 263685)
# Bonus_trans (0, 86)
# Flight_miles_12mo (0, 30817)
# Flight_trans_12 (0, 53)
# Days_since_enroll (2, 8296)
# Award? (0, 1)

# %%
df1=df.drop(columns=['cc1_miles', 'cc2_miles', 'cc3_miles','Award?'],axis=1)
#as there is no null values so no need of imputation

# %%
df1
# Out:
#        ID#  Balance  Qual_miles  Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# 0        1    28143           0          174            1                  0
# 1        2    19244           0          215            2                  0
# 2        3    41354           0         4123            4                  0
# 3        4    14776           0          500            1                  0
# 4        5    97752           0        43300           26               2077
# ...    ...      ...         ...          ...          ...                ...
# 3994  4017    18476           0         8525            4                200
# 3995  4018    64385           0          981            5                  0
# 3996  4019    73597           0        25447            8                  0
# 3997  4020    54899           0          500            1                500
# 3998  4021     3016           0            0            0                  0
#
#       Flight_trans_12  Days_since_enroll
# 0                   0               7000
# 1                   0               6968
# 2                   0               7034
# 3                   0               6952
# 4                   4               6935
# ...               ...                ...
# 3994                1               1403
# 3995                0               1395
# 3996                0               1402
# 3997                1               1401
# 3998                0               1398
#
# [3999 rows x 8 columns]

# %%
x=df1.iloc[:,1:].values
#feature scaling
sc_x=StandardScaler()
x=sc_x.fit_transform(x)
x
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.02786266e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.39545434e+00],
#        [-5.39456874e-01, -1.86298687e-01, -7.01088399e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.37995704e+00],
#        [-3.20031232e-01, -1.86298687e-01, -5.39252702e-01, ...,
#         -3.28603258e-01, -3.62167870e-01,  1.41192021e+00],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  3.43803696e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31560393e+00],
#        [-1.85606976e-01, -1.86298687e-01, -6.89286154e-01, ...,
#          2.85309024e-02, -9.85033311e-02, -1.31608822e+00],
#        [-7.00507951e-01, -1.86298687e-01, -7.09991847e-01, ...,
#         -3.28603258e-01, -3.62167870e-01, -1.31754109e+00]])

# %%
dendrogram=sch.dendrogram(sch.linkage(x,method='ward'))

# %%
cl=AC(n_clusters=7,linkage='ward',affinity='euclidean')
y_pr=cl.fit_predict(x)

# %%
df['cluster']=cl.labels_

# %%
df[df['cluster']==0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 6        7    84914           0          3          1          1        27482
# 9       10   104860           0          3          1          1        28426
# 10      11    40091           0          2          1          1         7278
# 11      12    96522           0          5          1          1        61105
# 12      13    43382           0          2          1          1        11150
# ...    ...      ...         ...        ...        ...        ...          ...
# 3974  3997    58387           0          3          1          1        14581
# 3978  4001    10071           0          2          1          1        27701
# 3980  4003    28867           0          3          1          1        19169
# 3985  4008    59017           0          4          1          1        34746
# 3991  4014    39142           0          3          1          1        14981
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
#
# 1911           25               7400               23               3985
# 1930           18              10042                4               3925
# 2015           65              22100               45               3831
# 2058           23              11408               23               4331
# 2151           37               9550               20               4008
# 2179           21               5688               20               3811
# 2217           27               7600               24               3739
# 2375           29               9150               26               3530
# 2449           10               8389                9               3259
# 2656           28              10850               26               2511
# 2696           37              12000               24               2395
# 2709           46               9729               29               2329
# 2751           19               9000               18               2217
# 2775           49               4550               24               2184
# 2789           39               4723               31               2108
# 2903           29               2900               29               1804
# 2999           47               4650               24               3206
# 3082           27               4673               21               2927
# 3096           36               7974               19               2691
# 3105           32               4800               23               2480
# 3165           25               6647               12               2424
# 3235           58              12873               53               2272
# 3282           24               7550               23               2272
# 3429           43               7000               22               1529
# 3463           23              15533               17               1041
# 3583           86              30817               53               1373
# 3594           68              14050               46               1325
# 3788           31               5000               14               3463
# 3846           51               7650               26               1665
# 3934            2               9577                1               1515
#
#       Award?  cluster
# 65         1        1
# 135        1        1
# 323        1        1
# 475        1        1
# 511        1        1
# 531        1        1
# 549        1        1
# 622        1        1
# 662        1        1
# 702        1        1
# 914        1        1
# 958        1        1
# 976        0        1
# 1014       0        1
# 1187       1        1
# 1236       0        1
# 1433       1        1
# 1489       1        1
# 1529       1        1
# 1593       1        1
# 1620       1        1
# 1676       1        1
# 1885       1        1
# 1911       1        1
# 1930       1        1
# 2015       1        1
# 2058       0        1
# 2151       1        1
# 2179       0        1
# 2217       1        1
# 2375       1        1
# 2449       0        1
# 2656       1        1
# 2696       1        1
# 2709       1        1
# 2751       1        1
# 2775       1        1
# 2789       1        1
# 2903       0        1
# 2999       1        1
# 3082       1        1
# 3096       0        1
# 3105       1        1
# 3165       1        1
# 3235       1        1
# 3282       1        1
# 3429       1        1
# 3463       1        1
# 3583       1        1
# 3594       1        1
# 3788       1        1
# 3846       1        1
# 3934       0        1

# %%
df.iloc[:,1:].groupby('cluster').agg('mean').reset_index().sort_values('Balance')
# Out:
#    cluster        Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# 6        6   34838.289855     1.127329   1.238095   1.014493   1.000000
# 5        5   40262.394012     0.598802   1.065868   1.000000   1.001198
# 0        0   79910.013241   123.694876   2.884283   1.018423   1.022453
# 4        4  107394.345725   153.776952   2.293680   1.033457   1.018587
# 3        3  135318.020833  5870.062500   1.916667   1.000000   1.000000
# 1        1  154830.603774   490.716981   1.943396   1.056604   1.000000
# 2        2  490821.571429   117.912088   3.604396   1.000000   1.043956
#
#     Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# 6   4522.862319     5.523810          98.812629         0.336439
# 5   2644.347305     2.768862         182.238323         0.584431
# 0  26735.156592    16.832470         148.672424         0.483592
# 4  25488.944238    20.438662        2777.936803         8.066914
# 3  16406.000000    12.645833         974.770833         3.270833
# 1  32137.018868    33.471698        8752.622642        23.679245
# 2  68119.582418    17.923077         834.659341         2.835165
#
#    Days_since_enroll    Award?
# 6        1825.105590  0.207039
# 5        5228.380838  0.225150
# 0        4727.468048  0.450201
# 4        4261.687732  0.646840
# 3        4320.375000  0.520833
# 1        4046.830189  0.830189
# 2        6170.362637  0.747253

# %% [markdown]
# # insights
# from data it is evident that avg no. of days_since_enroll doesn't mean that no. of miles eligible for award travel will be more.
# from data it is evident that avg flight_miles_12mo,Bonus_trans,Bonus_miles  has a direct positive relation with no. of miles eligible for award travel.
